# %%
import plot_probe_results as g
import importlib

importlib.reload(g)


results_datapath = '../probe_experiment_tracking.json'
model_prefixes=["lichess_karvhyp","random_karvhypNSNR"]
model_prefixes_random=["random_karvhypNSNR"]
model_prefixes_lichess=["lichess_karvhyp"]
max_train_games_list=["10000"]
num_epochs_list=[3]
probe_datasets=["lichess"]
training_configs=["classic"]
accuracy_types=["random","lichess"] #random, lichess, training set
#color_means="num_epochs",
line_means="probe_dataset"
marker_means="accuracy_type"
color_means="model_prefix"


g.plot_accuracy_by_iterations(
    results_datapath,
    model_prefixes,
    max_train_games_list,
    num_epochs_list,
    probe_datasets,
    training_configs,
    accuracy_types,
    color_means,
    line_means,
    marker_means,
    debugging=-2
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 22
#      18 marker_means="accuracy_type"
#      19 color_means="model_prefix"
# ---> 22 g.plot_accuracy_by_iterations(
#      23     results_datapath,
#      24     model_prefixes,
#      25     max_train_games_list,
#      26     num_epochs_list,
#      27     probe_datasets,
#      28     training_configs,
#      29     accuracy_types,
#      30     color_means,
#      31     line_means,
#      32     marker_means,
#      33     debugging=-2
#      34 )
#
# File ~/chess_interpretability/ploting/plot_probe_results.py:312, in plot_accuracy_by_iterations(results_datapath, model_prefixes, max_train_games_list, num_epochs_list, probe_datasets, training_configs, accuracy_types, color_means, line_means, marker_means, debugging)
#     310                 print(f"ploting {iterations} with {accuracy} color {color} linestyle {line_style} marker {marker} label {label}")
#     311 for prefix, probe_dataset, acc_type in product(model_prefixes, probe_datasets, accuracy_types):
# --> 312     ax.plot(
#     313         all_info[prefix][probe_dataset][acc_type]["iterations"],
#     314         all_info[prefix][probe_dataset][acc_type]["accuracies"],
#     315         color=all_info[prefix][probe_dataset][acc_type]["color"],
#     316         linestyle=all_info[prefix][probe_dataset][acc_type]["line_style"],
#     317         marker=all_info[prefix][probe_dataset][acc_type]["marker"],
#     318         label=all_info[prefix][probe_dataset][acc_type]["label"]
#     319                 )
#     321 # --- 7) Create custom legends
#     322
#     323 # Legend for Colors
#     324 if color_means:
#
# File ~/chess_interpretability/env/lib/python3.12/site-packages/matplotlib/axes/_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File ~/chess_interpretability/env/lib/python3.12/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/chess_interpretability/env/lib/python3.12/site-packages/matplotlib/axes/_base.py:539, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     537     return list(result)
#     538 else:
# --> 539     return [l[0] for l in result]
#
# File ~/chess_interpretability/env/lib/python3.12/site-packages/matplotlib/axes/_base.py:532, in <genexpr>(.0)
#     529 else:
#     530     labels = [label] * n_datasets
# --> 532 result = (make_artist(axes, x[:, j % ncx], y[:, j % ncy], kw,
#     533                       {**kwargs, 'label': label})
#     534           for j, label in enumerate(labels))
#     536 if return_kwargs:
#     537     return list(result)
#
# File ~/chess_interpretability/env/lib/python3.12/site-packages/matplotlib/axes/_base.py:346, in _process_plot_var_args._makeline(self, axes, x, y, kw, kwargs)
#     344 default_dict = self._getdefaults(set(), kw)
#     345 self._setdefaults(default_dict, kw)
# --> 346 seg = mlines.Line2D(x, y, **kw)
#     347 return seg, kw
#
# File ~/chess_interpretability/env/lib/python3.12/site-packages/matplotlib/lines.py:376, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     373 self.set_drawstyle(drawstyle)
#     375 self._color = None
# --> 376 self.set_color(color)
#     377 if marker is None:
#     378     marker = 'none'  # Default.
#
# File ~/chess_interpretability/env/lib/python3.12/site-packages/matplotlib/lines.py:1061, in Line2D.set_color(self, color)
#    1053 def set_color(self, color):
#    1054     """
#    1055     Set the color of the line.
#    1056
#    (...)
#    1059     color : color
#    1060     """
# -> 1061     mcolors._check_color_like(color=color)
#    1062     self._color = color
#    1063     self.stale = True
#
# File ~/chess_interpretability/env/lib/python3.12/site-packages/matplotlib/colors.py:246, in _check_color_like(**kwargs)
#     244 for k, v in kwargs.items():
#     245     if not is_color_like(v):
# --> 246         raise ValueError(f"{v!r} is not a valid value for {k}")
#
# ValueError: '' is not a valid value for color

# %%
import json

with open(results_datapath, 'r', encoding='utf-8') as f:
    data = json.load(f)

for row in data:
    if 'test_results' not in row:
        row["test_results"] = {}

with open("buffer", 'w', encoding='utf-8') as f:
    json.dump(data,f,indent=2)

# %%
import plot_probe_loss as g
import importlib

importlib.reload(g)


results_datapath = 'probe_experiment_tracking.json'
model_prefixes=["lichess_karvhypNSNR_300K"]
max_train_games_list=["10000"]
num_epochs_list=["3"],
probe_datasets=["random"]
training_configs=["classic"]
min_epochs = 3
max_epochs = 100

g.plot_probe_loss(
    results_datapath,
    model_prefixes,
    training_configs,
    probe_datasets,
    max_train_games_list,
    min_epochs,
    max_epochs 
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
